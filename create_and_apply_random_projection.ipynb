# %% [markdown]
# #  Creating and applying a random projection
# In this file we will create and apply a random projection. Like in the associated paper we will be defining the size of the random project to be the same as an existing featurisation method, but random projections can be as big or small as you'd like.

# %% [markdown]
# ## First some imports and setting some variables

# %%
import pandas as pd
import json
import os
from utilities import featurise_data
import numpy as np

# %%
data_folder = 'data/case_studies'
task_info = 'task_info.json'
with open(task_info) as f:
    tasks = json.load(f)

# %%
task = 'GFA'
featurisation = 'oliynyk'

# %% [markdown]
# ## Now lets read in the data we are projection

# %%
data_file = os.path.join(data_folder, #were the data is
             'CBFV_data', #whether we are investigating CBFVs or random projections
             tasks[task]['study_folder'], #Which study?
             '80_20_split', #80_20_split or LOCO-CV?
             tasks[task]['type'], #regression or classification?
             tasks[task]['task_folder'], #Which task?
             f'{featurisation}_train_CBFV.csv') #Which file 

df = pd.read_csv(data_file)

# %%
n_dims = len(df.drop(['target','formula'],axis=1).columns)
formulae = df[['formula']]
print(f'We will be making a projectioning {len(formulae)} compositions to a representation of size {n_dims}')
# Out:
# We will be making a projectioning 5051 compositions to a representation of size 176

# %% [markdown]
# ## Now we get the CompVec representation, and create and apply the random projection

# %%
compVec = featurise_data(formulae, style='compVec').drop("formula",axis=1)

# %%
projection = np.random.normal(loc=0, scale=1/n_dims, size=(compVec.shape[1],n_dims))

# %%
projected = compVec @ projection

# %% [markdown]
# ## Now we have our projected data

# %%
projected
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.004696  0.008477  0.009697 -0.002044  0.002059  0.005453  0.002163
# 1     0.003654  0.008134  0.007971 -0.001110  0.001714  0.001781 -0.000628
# 2     0.000344  0.005277  0.005106 -0.000874  0.004584 -0.002815 -0.008326
# 3    -0.002190 -0.002294  0.010288 -0.002258 -0.000787  0.006352 -0.000709
# 4     0.001079 -0.000765  0.000367  0.006792 -0.004939 -0.009229 -0.008557
# ...        ...       ...       ...       ...       ...       ...       ...
# 5046  0.005617  0.003161 -0.001203 -0.000988 -0.002067  0.000184  0.001516
# 5047  0.003763  0.006747  0.008938 -0.001211  0.001750  0.005361  0.001494
# 5048  0.001924  0.005319 -0.003625  0.000993 -0.004422  0.003266 -0.000972
# 5049  0.003407  0.004260  0.003227 -0.007356  0.003336  0.000983  0.002709
# 5050  0.001107 -0.002522  0.000818  0.001449 -0.007164  0.001272 -0.002817
#
#            7         8         9    ...       166       167       168  \
# 0     0.003585 -0.008053  0.009997  ... -0.000378  0.007234 -0.009553
# 1     0.002380 -0.004014  0.008025  ... -0.001277  0.003906 -0.009409
# 2    -0.008085  0.000375 -0.001643  ...  0.000699  0.001135 -0.004511
# 3     0.005300  0.000603 -0.003100  ...  0.002507  0.004216 -0.004654
# 4     0.002427 -0.006126  0.000623  ... -0.001119 -0.005436  0.006842
# ...        ...       ...       ...  ...       ...       ...       ...
# 5046  0.000683  0.001370 -0.001385  ...  0.002007 -0.002158 -0.000615
# 5047  0.003917 -0.007268  0.009291  ... -0.001094  0.007180 -0.008452
# 5048 -0.001886  0.000752 -0.012084  ... -0.004042 -0.004034 -0.001259
# 5049 -0.000500 -0.002336  0.005366  ...  0.004364  0.005377 -0.004423
# 5050  0.002577 -0.000185 -0.001777  ... -0.001626  0.000903 -0.005944
#
#            169       170       171       172       173       174       175
# 0     0.003809  0.002923 -0.002038  0.004748 -0.006332 -0.004224 -0.005601
# 1     0.003256 -0.000068 -0.002007  0.004817 -0.004591 -0.004084 -0.004689
# 2    -0.004686 -0.000307  0.003646 -0.002054 -0.000356 -0.005384 -0.003322
# 3     0.001643  0.002835  0.008628 -0.007847  0.000406 -0.000967 -0.001147
# 4     0.001086 -0.007351  0.002776 -0.003052  0.011181  0.001295  0.004980
# ...        ...       ...       ...       ...       ...       ...       ...
# 5046 -0.005025 -0.003663  0.001353  0.001946  0.004328  0.000332 -0.000792
# 5047  0.003579  0.001857 -0.002510  0.003726 -0.005219 -0.003484 -0.004621
# 5048  0.005118 -0.002348  0.003460 -0.007758  0.000761 -0.001356 -0.001650
# 5049  0.001541  0.001982 -0.001291  0.005048 -0.002685 -0.001350 -0.007002
# 5050 -0.005377  0.001598 -0.001319 -0.002453  0.004378 -0.005476  0.001650
#
# [5051 rows x 176 columns]
